# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold
from sklearn.metrics import accuracy_score, log_loss, r2_score
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.svm import SVC, SVR
from sklearn.linear_model import ElasticNet, LinearRegression
from xgboost import XGBClassifier, XGBRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import BaseEnsemble, VotingClassifier, GradientBoostingClassifier, RandomForestClassifier, StackingClassifier, StackingRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train_v9rqX0R.csv')
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
train['Item_Fat_Content'].replace({'low fat': 'Low Fat', 
                                  'LF': 'Low Fat',
                                  'reg': 'Regular'}, inplace=True)

# %%
train_items = train[['Item_Identifier', 'Item_Weight']]

# %%
train_items.isna().sum()
# Out:
# Item_Identifier       0
# Item_Weight        1463
# dtype: int64

# %%
train_items.drop_duplicates(inplace=True)

# %%
train_items.dropna(inplace=True)

# %%
train_items.isna().sum()
# Out:
# Item_Identifier    0
# Item_Weight        0
# dtype: int64

# %%
train1 = pd.merge(train, train_items)

# %%
train.isna().sum()
train1.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDH17       16.200          Regular         0.016687
# 8           FDU28       19.200          Regular         0.094450
# 9           FDY07       11.800          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7           Frozen Foods   96.9726            OUT045
# 8           Frozen Foods  187.8214            OUT017
# 9  Fruits and Vegetables   45.5402            OUT049
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       2002         NaN               Tier 2
# 8                       2007         NaN               Tier 2
# 9                       1999      Medium               Tier 1
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type1          1076.5986
# 8  Supermarket Type1          4710.5350
# 9  Supermarket Type1          1516.0266

# %%
# train[train['Item_Fat_Content'] == 'low fat'] = 'Low Fat'
# train[train['Item_Fat_Content'] == 'LF'] = 'Low Fat'
# train[train['Item_Fat_Content'] == 'reg'] = 'Regular'

# train['Item_Fat_Content'].unique()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
temp = train.groupby('Item_Identifier')
temp

# %%
temp['Item_Weight'].unique()
# Out:
# Item_Identifier
# DRA12          [11.6]
# DRA24    [19.35, nan]
# DRA59     [8.27, nan]
# DRB01     [7.39, nan]
# DRB13         [6.115]
#              ...
# NCZ30     [6.59, nan]
# NCZ41         [19.85]
# NCZ42          [10.5]
# NCZ53      [9.6, nan]
# NCZ54    [14.65, nan]
# Name: Item_Weight, Length: 1559, dtype: object

# %%
temp['Item_Weight'].mean()
# Out:
# Item_Identifier
# DRA12    11.600
# DRA24    19.350
# DRA59     8.270
# DRB01     7.390
# DRB13     6.115
#           ...
# NCZ30     6.590
# NCZ41    19.850
# NCZ42    10.500
# NCZ53     9.600
# NCZ54    14.650
# Name: Item_Weight, Length: 1559, dtype: float64

# %%
train['Item_Weight'].fillna(temp['Item_Weight'].mean())
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
train =train.groupby('Item_Identifier')['Item_Weight'].apply(lambda x:x.fillna(x.mean())).reset_index()
train.isna().sum()
# Out:
# Item_Identifier    0
# level_1            0
# Item_Weight        4
# dtype: int64

# %%
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
def cleaner(df):
    df['Item_Fat_Content'].replace({'low fat': 'Low Fat', 
                                  'LF': 'Low Fat',
                           'reg': 'Regular'}, inplace=True)
    return df
def helper(df_train, df_train): 
    df = pd.concat([df_train, df_test])
    df = df[['Item_Identifier', 'Item_Weight']]
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    return df

# %%
train = pd.read_csv('train_v9rqX0R.csv')
test = pd.read_csv('test_AbJTz2l.csv')

test.shape
# Out:
# (5681, 11)

# %%
train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train = cleaner(train)
test = cleaner(test)

# %%
train['Outlet_Size'].fillna(value='small', inplace=True)
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test['Outlet_Size'].fillna(value='small', inplace=True)
test.isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                  976
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                    0
# Outlet_Location_Type           0
# Outlet_Type                    0
# dtype: int64

# %%
df = helper(train, test)

# train = pd.merge(train, df)
# test = pd.merge(test, df)
# test.isnull().sum()

# %%
test.isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                  976
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                    0
# Outlet_Location_Type           0
# Outlet_Type                    0
# dtype: int64

# %%
test.shape
# Out:
# (5681, 11)

# %%
# X_train = pd.get_dummies(train.drop('Item_Outlet_Sales', axis=1), 
#                          drop_first=True)

y_train =train['Item_Outlet_Sales']

# %%
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

ct = make_column_transformer((ohe, make_column_selector(dtype_include=object)),('passthrough', make_column_selector(dtype_exclude=object))).set_output(transform ='pandas')

# %%
X_train = ct.fit_transform(train.drop('Item_Outlet_Sales', axis=1))
X_test = ct.transform(test)

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
train['Item_Identifier'] = train['Item_Identifier'].astype(str)
df['Item_Identifier'] = df['Item_Identifier'].astype(str)

# Create a dictionary from the 'df' dataframe
dict_df = df.set_index('Item_Identifier')['Item_Weight'].to_dict()

# Use the map function to fill NaN values
train['Item_Weight'] = train['Item_Weight'].fillna(train['Item_Identifier'].map(dict_df))

# %%
test['Item_Identifier'] = test['Item_Identifier'].astype(str)
df['Item_Identifier'] = df['Item_Identifier'].astype(str)

# Create a dictionary from the 'df' dataframe
dict_df = df.set_index('Item_Identifier')['Item_Weight'].to_dict()

# Use the map function to fill NaN values
test['Item_Weight'] = test['Item_Weight'].fillna(test['Item_Identifier'].map(dict_df))

# %%
df
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8471           NCT53        5.400
# 59             FDE52       10.395
# 396            FDN52        9.395
# 440            FDQ60        6.195
# 1163           FDK57       10.195
#
# [1559 rows x 2 columns]

# %%
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300          Regular         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007       small               Tier 2
# 2                          1998       small               Tier 3
# 3                          2007       small               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002       small               Tier 2
# 5679                       2007       small               Tier 2
# 5680                       2002       small               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
test1.shape
# Out:
# (5681, 12)

# %%
test = cleaner(test)
test = pd.merge(test, df, how ='left')
test['Outlet_Size'].fillna(value='small', inplace=True)
test.isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                  976
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                    0
# Outlet_Location_Type           0
# Outlet_Type                    0
# dtype: int64

# %%
test.shape
# Out:
# (5681, 11)

# %%
y_test = ct.transform(test)

# %%
y_pred = lr.predict(y_test)

# %%
y_pred[y_pred<0]=0

# %%
 submit = pd.DataFrame({'Item_Identifier':test['Item_Identifier'], 'Outlet_Identifier':test['Outlet_Identifier'], 'Item_Outlet_Sales': y_pred})

# %%
submit.to_csv("lr.csv", index =False)

# %%
def outlet_func(train, test):
    df = pd.concat([train, test])
    # print(df.shape)
    df = df[['Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type']]
    df.drop_duplicates(inplace=True)
    # df.dropna(inplace=True)
    return df

# %%
outlet = outlet_func(train, test)
outlet
# Out:
# (14204, 12)
#    Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0             OUT049                       1999      Medium
# 1             OUT018                       2009      Medium
# 3             OUT010                       1998         NaN
# 4             OUT013                       1987        High
# 7             OUT027                       1985      Medium
# 8             OUT045                       2002         NaN
# 9             OUT017                       2007         NaN
# 11            OUT046                       1997       Small
# 19            OUT035                       2004       Small
# 23            OUT019                       1985       Small
#
#    Outlet_Location_Type        Outlet_Type
# 0                Tier 1  Supermarket Type1
# 1                Tier 3  Supermarket Type2
# 3                Tier 3      Grocery Store
# 4                Tier 3  Supermarket Type1
# 7                Tier 3  Supermarket Type3
# 8                Tier 2  Supermarket Type1
# 9                Tier 2  Supermarket Type1
# 11               Tier 1  Supermarket Type1
# 19               Tier 2  Supermarket Type1
# 23               Tier 1      Grocery Store

# %%
con_df =  pd.concat([train, test])
X = con_df[['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Type', 'Outlet_Size']]
y = con_df[['Outlet_Size']]

# %%
con_df =  pd.concat([train, test])
X = con_df[['Outlet_Establishment_Year','Outlet_Location_Type','Outlet_Type', 'Outlet_Size']]
y = con_df[['Outlet_Size']]

X_train = X.dropna()
y_train = y.dropna()


X_test = X[X['Outlet_Size'].isna()]
y_test = y[y['Outlet_Size'].isna()]

dum = X.dropna()

# %%
le = LabelEncoder()

dum = le.fit_transform(dum[])

y = dum['Outlet_Size']


X = dum.drop('Outlet_Size',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 3
#       1 le = LabelEncoder()
# ----> 3 dum = le.fit_transform(dum)
#       5 y =dum['Outlet_Size']
#       8 X = dum.drop('Outlet_Size',axis=1)
#
# File c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\preprocessing\_label.py:114, in LabelEncoder.fit_transform(self, y)
#     101 def fit_transform(self, y):
#     102     """Fit label encoder and return encoded labels.
#     103
#     104     Parameters
#    (...)
#     112         Encoded labels.
#     113     """
# --> 114     y = column_or_1d(y, warn=True)
#     115     self.classes_, y = _unique(y, return_inverse=True)
#     116     return y
#
# File c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\utils\validation.py:1367, in column_or_1d(y, dtype, warn)
#    1356         warnings.warn(
#    1357             (
#    1358                 "A column-vector y was passed when a 1d array was"
#    (...)
#    1363             stacklevel=2,
#    1364         )
#    1365     return _asarray_with_order(xp.reshape(y, (-1,)), order="C", xp=xp)
# -> 1367 raise ValueError(
#    1368     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1369 )
#
# ValueError: y should be a 1d array, got an array of shape (10188, 4) instead.

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10188, 4)
# (4016, 4)
# (10188, 1)
# (4016, 1)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.naive_bayes import BernoulliNB


br = BernoulliNB()
br.fit(X_train, y_train)
y_pred = br.predict(X_test)
y_pred_prob = br.predict_proba(X_test)

print(accuracy_score(y_test, y_pred))
print(roc_auc_score(y_test, y_pred_prob[:,1]))
print(log_loss(y_test, y_pred_prob))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17824\2540720332.py in ?()
#       2 from sklearn.naive_bayes import BernoulliNB
#       3
#       4
#       5 br = BernoulliNB()
# ----> 6 br.fit(X_train, y_train)
#       7 y_pred = br.predict(X_test)
#       8 y_pred_prob = br.predict_proba(X_test)
#       9
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\naive_bayes.py in ?(self, X, y, sample_weight)
#     728         -------
#     729         self : object
#     730             Returns the instance itself.
#     731         """
# --> 732         X, y = self._check_X_y(X, y)
#     733         _, n_features = X.shape
#     734
#     735         labelbin = LabelBinarizer()
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\naive_bayes.py in ?(self, X, y, reset)
#    1183     def _check_X_y(self, X, y, reset=True):
# -> 1184         X, y = super()._check_X_y(X, y, reset=reset)
#    1185         if self.binarize is not None:
#    1186             X = binarize(X, threshold=self.binarize)
#    1187         return X, y
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\naive_bayes.py in ?(self, X, y, reset)
#     576     def _check_X_y(self, X, y, reset=True):
#     577         """Validate X and y in fit methods."""
# --> 578         return self._validate_data(X, y, accept_sparse="csr", reset=reset)
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259         raise ValueError(
#    1260             f"{estimator_name} requires y to be passed, but the target y is None"
#    1261         )
#    1262
# -> 1263     X = check_array(
#    1264         X,
#    1265         accept_sparse=accept_sparse,
#    1266         accept_large_sparse=accept_large_sparse,
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Tier 1'
