# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold
from sklearn.metrics import accuracy_score, log_loss
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.svm import SVC, SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import BaseEnsemble, VotingClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import warnings
warnings.filterwarnings('ignore')

# %%
kyp = pd.read_csv(r'..\Cases\Kyphosis\Kyphosis.csv')
kyp.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
# replace = False: no repeatition
kyp_ind = list(kyp.index)
samp_ind = np.random.choice(kyp_ind, size = 60, replace = False)
samp_kyp = kyp.iloc[samp_ind,:]
# samp_kyp.shape

samp_ind
# Out:
# array([ 4, 39, 72, 36, 31, 26, 41, 63, 12, 55, 54, 16, 38,  6, 22, 71, 24,
#         5, 11, 44, 80, 49, 18,  1, 67, 53, 23, 56, 33, 77, 20, 42,  2, 50,
#        73, 58, 66, 32, 76, 47, 21, 29, 35, 60, 25, 15,  8, 79, 74, 69, 37,
#        27,  9, 51, 75, 62, 48, 78, 57, 19])

# %%
kyp_ind = list(kyp.index)
samp_ind = np.random.choice(kyp_ind, size = 60, replace = True)
samp_kyp = kyp.iloc[samp_ind,:]
# samp_kyp.shape
samp_ind
# Out:
# array([59, 55, 33, 80, 11, 46,  0, 39, 56,  4, 24, 74, 13,  4, 47, 56, 66,
#         4, 48, 58, 50, 39, 12, 70, 25, 25, 30, 79, 77, 72, 79,  4, 28,  4,
#        16, 72, 54, 12, 62, 54,  2, 78, 41, 45, 10, 11, 57, 48, 43, 56, 28,
#        63, 55, 49,  9, 71, 64, 44, 15, 18])

# %%
le = LabelEncoder()
y = le.fit_transform(kyp['Kyphosis'])
X = kyp.drop('Kyphosis', axis=1)
print(X)
# Out:
#     Age  Number  Start
# 0    71       3      5
# 1   158       3     14
# 2   128       4      5
# 3     2       5      1
# 4     1       4     15
# ..  ...     ...    ...
# 76  157       3     13
# 77   26       7     13
# 78  120       2     13
# 79   42       7      6
# 80   36       4     13
#
# [81 rows x 3 columns]

# %%
lr = LogisticRegression()
bagg = BaggingClassifier(lr, n_estimators= 25, n_jobs=-1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=24, stratify=y)

# %%
bagg.fit(X_train, y_train)
y_pred = bagg.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.72

# %%
y_pred_prob = bagg.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob))
# Out:
# 0.44676747657989346

# %%
dct = DecisionTreeClassifier()
bagg = BaggingClassifier(lr, n_estimators= 25, n_jobs=-1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=24, stratify=y)

# %%
bagg.fit(X_train, y_train)
y_pred = bagg.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.72

# %%
y_pred_prob = bagg.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob))
# Out:
# 0.47804928298878563

# %%
params = {'C': [0.1,1,1.5,0.5,2,3]}
kfold = StratifiedKFold(n_splits=5,random_state=24, shuffle=True )
svm = SVC(kernel='linear', random_state=24)
gcv = GridSearchCV(svm, param_grid = params, cv= kfold, scoring='neg_log_loss')
gcv.fit(X, y)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=SVC(kernel='linear', random_state=24),
#              param_grid={'C': [0.1, 1, 1.5, 0.5, 2, 3]},
#              scoring='neg_log_loss')

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# nan
# {'C': 0.1}
